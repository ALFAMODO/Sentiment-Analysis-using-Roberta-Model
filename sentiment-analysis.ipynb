# %% [markdown]
# ## Sentiment Analysis in Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
import nltk

# %%
df = pd.read_csv('Reviews.csv')
df = df.head(500)

# %%
ax = df['Score'].value_counts().sort_index().plot(kind='bar', title='Count of reviews', figsize=(10,5))
ax.set_xlabel('Reviews Stars')
plt.show()

# %%
example = df['Text'][50]
example
# Out:
# "This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go."

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 8] nodename nor
# [nltk_data]     servname provided, or not known>
# False

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Error loading averaged_perceptron_tagger: <urlopen error
# [nltk_data]     [Errno 8] nodename nor servname provided, or not
# [nltk_data]     known>
# False

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Error loading maxent_ne_chunker: <urlopen error [Errno 8]
# [nltk_data]     nodename nor servname provided, or not known>
# [nltk_data] Downloading package words to /Users/shikshit/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# # VADER Sentiment Scoring

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shikshit/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
res = {}
for _, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
#metadata with sentiment scores 
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index':'Id'})
vaders = vaders.merge(df, on='Id', how='left')

# %%
vaders
# Out:
#       Id    neg    neu    pos  compound   ProductId          UserId  \
# 0      1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1      2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2      3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3      4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4      5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
# ..   ...    ...    ...    ...       ...         ...             ...
# 495  496  0.000  0.554  0.446    0.9725  B000G6RYNE   APGAA43E3WPN7
# 496  497  0.059  0.799  0.142    0.7833  B000G6RYNE    ABR7HU5H1KNE
# 497  498  0.025  0.762  0.212    0.9848  B000G6RYNE   AJQD2WWJYOYFQ
# 498  499  0.041  0.904  0.055    0.1280  B000G6RYNE  A16YH487W9ZYO0
# 499  500  0.000  0.678  0.322    0.9811  B000G6RYNE   A83YQC1XOU4CS
#
#                          ProfileName  HelpfulnessNumerator  \
# 0                         delmartian                     1
# 1                             dll pa                     0
# 2    Natalia Corres "Natalia Corres"                     1
# 3                               Karl                     3
# 4      Michael D. Bigham "M. Wassir"                     0
# ..                               ...                   ...
# 495                           Darren                     0
# 496                            Keith                     0
# 497                          bubbles                     0
# 498                 Bruce G. Lindsay                     0
# 499                         J. Baker                     0
#
#      HelpfulnessDenominator  Score        Time  \
# 0                         1      5  1303862400
# 1                         0      1  1346976000
# 2                         1      4  1219017600
# 3                         3      2  1307923200
# 4                         0      5  1350777600
# ..                      ...    ...         ...
# 495                       0      5  1201392000
# 496                       0      5  1196726400
# 497                       0      4  1186617600
# 498                       0      4  1184198400
# 499                       0      5  1183420800
#
#                              Summary  \
# 0              Good Quality Dog Food
# 1                  Not as Advertised
# 2              "Delight" says it all
# 3                     Cough Medicine
# 4                        Great taffy
# ..                               ...
# 495                    amazing chips
# 496                   Best Chip Ever
# 497  Tangy, spicy, and sweet- oh my!
# 498        An indulgence with a bite
# 499                The best I've had
#
#                                                   Text
# 0    I have bought several of the Vitality canned d...
# 1    Product arrived labeled as Jumbo Salted Peanut...
# 2    This is a confection that has been around a fe...
# 3    If you are looking for the secret ingredient i...
# 4    Great taffy at a great price.  There was a wid...
# ..                                                 ...
# 495  i rarely eat chips but i saw these and tried t...
# 496  This is easily the best potato chip that I hav...
# 497  Kettle Chips Spicy Thai potato chips have the ...
# 498  Okay, I should not eat potato chips, nor shoul...
# 499  I don't write very many reviews but I have to ...
#
# [500 rows x 14 columns]

# %%
ax = sns.barplot(data=vaders, x='Score', y='compound')
ax.set_title("compound score by amazon star reviews")
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,5))
sns.barplot(data=vaders, x='Score', y='pos', ax=ax[0])
sns.barplot(data=vaders, x='Score', y='neu', ax=ax[1])
sns.barplot(data=vaders, x="Score", y="neg", ax=ax[2])
ax[0].set_title('Positive')
ax[1].set_title('Neutral')
ax[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Roberta Pretrained Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f'cardiffnlp/twitter-roberta-base-sentiment'
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# /Users/shikshit/anaconda3/envs/dlenv/lib/python3.11/site-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
print(example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
#Roberta Model

encoded_text = tokenizer(example, return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)
scores
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
}
print(scores_dict)
# Out:
# {'roberta_neg': 0.97635514, 'roberta_neu': 0.020687463, 'roberta_pos': 0.0029573694}

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res={}
for i, row in tqdm(df.iterrows(), total = len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f'vader_{key}'] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print('Broke for', myid)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for 83
# Broke for 187

# %%
from tqdm import tqdm

res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['Text']
        myid = row['Id']
        
        # Perform sentiment analysis using VADER
        vader_result = sia.polarity_scores(text)
        
        # Rename VADER result keys
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f'vader_{key}'] = value
        
        # Perform sentiment analysis using RoBERTa
        roberta_result = polarity_scores_roberta(text)
        
        # Merge VADER and RoBERTa results
        both = {**vader_result_rename, **roberta_result}
        
        # Store the results in the dictionary
        res[myid] = both
    except RuntimeError:
        print('Broke for', myid)
# Out:
#  17%|███████▏                                  | 86/500 [00:05<00:23, 17.43it/s]
# Broke for 83
#  38%|███████████████▌                         | 190/500 [00:12<00:18, 16.53it/s]
# Broke for 187
# 100%|█████████████████████████████████████████| 500/500 [00:34<00:00, 14.50it/s]

# %%
res
# Out:
# {1: {'vader_neg': 0.0,
#   'vader_neu': 0.695,
#   'vader_pos': 0.305,
#   'vader_compound': 0.9441,
#   'roberta_neg': 0.009624226,
#   'roberta_neu': 0.049980387,
#   'roberta_pos': 0.94039536},
#  2: {'vader_neg': 0.138,
#   'vader_neu': 0.862,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5664,
#   'roberta_neg': 0.5089858,
#   'roberta_neu': 0.4524137,
#   'roberta_pos': 0.038600426},
#  3: {'vader_neg': 0.091,
#   'vader_neu': 0.754,
#   'vader_pos': 0.155,
#   'vader_compound': 0.8265,
#   'roberta_neg': 0.0032289105,
#   'roberta_neu': 0.09806755,
#   'roberta_pos': 0.8987036},
#  4: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.0022951283,
#   'roberta_neu': 0.090219304,
#   'roberta_pos': 0.9074856},
#  5: {'vader_neg': 0.0,
#   'vader_neu': 0.552,
#   'vader_pos': 0.448,
#   'vader_compound': 0.9468,
#   'roberta_neg': 0.0016347276,
#   'roberta_neu': 0.010302456,
#   'roberta_pos': 0.98806286},
#  6: {'vader_neg': 0.029,
#   'vader_neu': 0.809,
#   'vader_pos': 0.163,
#   'vader_compound': 0.883,
#   'roberta_neg': 0.006129587,
#   'roberta_neu': 0.021795865,
#   'roberta_pos': 0.97207457},
#  7: {'vader_neg': 0.034,
#   'vader_neu': 0.693,
#   'vader_pos': 0.273,
#   'vader_compound': 0.9346,
#   'roberta_neg': 0.0013047539,
#   'roberta_neu': 0.007773786,
#   'roberta_pos': 0.99092144},
#  8: {'vader_neg': 0.0,
#   'vader_neu': 0.52,
#   'vader_pos': 0.48,
#   'vader_compound': 0.9487,
#   'roberta_neg': 0.002029356,
#   'roberta_neu': 0.005685204,
#   'roberta_pos': 0.9922854},
#  9: {'vader_neg': 0.0,
#   'vader_neu': 0.851,
#   'vader_pos': 0.149,
#   'vader_compound': 0.6369,
#   'roberta_neg': 0.0038735901,
#   'roberta_neu': 0.094156526,
#   'roberta_pos': 0.9019699},
#  10: {'vader_neg': 0.0,
#   'vader_neu': 0.705,
#   'vader_pos': 0.295,
#   'vader_compound': 0.8313,
#   'roberta_neg': 0.003103466,
#   'roberta_neu': 0.05591225,
#   'roberta_pos': 0.9409843},
#  11: {'vader_neg': 0.017,
#   'vader_neu': 0.846,
#   'vader_pos': 0.137,
#   'vader_compound': 0.9746,
#   'roberta_neg': 0.01913407,
#   'roberta_neu': 0.07104432,
#   'roberta_pos': 0.9098216},
#  12: {'vader_neg': 0.113,
#   'vader_neu': 0.887,
#   'vader_pos': 0.0,
#   'vader_compound': -0.7579,
#   'roberta_neg': 0.37264287,
#   'roberta_neu': 0.5196991,
#   'roberta_pos': 0.107658096},
#  13: {'vader_neg': 0.031,
#   'vader_neu': 0.923,
#   'vader_pos': 0.046,
#   'vader_compound': 0.296,
#   'roberta_neg': 0.46612415,
#   'roberta_neu': 0.41525942,
#   'roberta_pos': 0.11861644},
#  14: {'vader_neg': 0.0,
#   'vader_neu': 0.355,
#   'vader_pos': 0.645,
#   'vader_compound': 0.9466,
#   'roberta_neg': 0.0014077479,
#   'roberta_neu': 0.0058832774,
#   'roberta_pos': 0.9927089},
#  15: {'vader_neg': 0.104,
#   'vader_neu': 0.632,
#   'vader_pos': 0.264,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.0018244234,
#   'roberta_neu': 0.021840984,
#   'roberta_pos': 0.9763346},
#  16: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.0045621274,
#   'roberta_neu': 0.03232538,
#   'roberta_pos': 0.96311253},
#  17: {'vader_neg': 0.097,
#   'vader_neu': 0.694,
#   'vader_pos': 0.209,
#   'vader_compound': 0.7481,
#   'roberta_neg': 0.0029225869,
#   'roberta_neu': 0.013419529,
#   'roberta_pos': 0.9836579},
#  18: {'vader_neg': 0.0,
#   'vader_neu': 0.61,
#   'vader_pos': 0.39,
#   'vader_compound': 0.8883,
#   'roberta_neg': 0.0011118244,
#   'roberta_neu': 0.008006255,
#   'roberta_pos': 0.9908819},
#  19: {'vader_neg': 0.012,
#   'vader_neu': 0.885,
#   'vader_pos': 0.103,
#   'vader_compound': 0.8957,
#   'roberta_neg': 0.0030300766,
#   'roberta_neu': 0.14215364,
#   'roberta_pos': 0.8548163},
#  20: {'vader_neg': 0.0,
#   'vader_neu': 0.863,
#   'vader_pos': 0.137,
#   'vader_compound': 0.6077,
#   'roberta_neg': 0.0055546425,
#   'roberta_neu': 0.0324693,
#   'roberta_pos': 0.96197605},
#  21: {'vader_neg': 0.0,
#   'vader_neu': 0.865,
#   'vader_pos': 0.135,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.010422187,
#   'roberta_neu': 0.065259375,
#   'roberta_pos': 0.9243185},
#  22: {'vader_neg': 0.0,
#   'vader_neu': 0.739,
#   'vader_pos': 0.261,
#   'vader_compound': 0.9153,
#   'roberta_neg': 0.0016783961,
#   'roberta_neu': 0.02074402,
#   'roberta_pos': 0.97757757},
#  23: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.7687,
#   'roberta_neg': 0.009479427,
#   'roberta_neu': 0.056938715,
#   'roberta_pos': 0.9335818},
#  24: {'vader_neg': 0.085,
#   'vader_neu': 0.771,
#   'vader_pos': 0.143,
#   'vader_compound': 0.2617,
#   'roberta_neg': 0.0032611743,
#   'roberta_neu': 0.02322298,
#   'roberta_pos': 0.97351587},
#  25: {'vader_neg': 0.038,
#   'vader_neu': 0.895,
#   'vader_pos': 0.068,
#   'vader_compound': 0.3939,
#   'roberta_neg': 0.44952786,
#   'roberta_neu': 0.39073434,
#   'roberta_pos': 0.15973783},
#  26: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.045313906,
#   'roberta_neu': 0.778621,
#   'roberta_pos': 0.17606512},
#  27: {'vader_neg': 0.128,
#   'vader_neu': 0.872,
#   'vader_pos': 0.0,
#   'vader_compound': -0.296,
#   'roberta_neg': 0.9533157,
#   'roberta_neu': 0.040582854,
#   'roberta_pos': 0.006101383},
#  28: {'vader_neg': 0.04,
#   'vader_neu': 0.808,
#   'vader_pos': 0.152,
#   'vader_compound': 0.5956,
#   'roberta_neg': 0.0038475832,
#   'roberta_neu': 0.02275417,
#   'roberta_pos': 0.97339827},
#  29: {'vader_neg': 0.022,
#   'vader_neu': 0.669,
#   'vader_pos': 0.309,
#   'vader_compound': 0.9913,
#   'roberta_neg': 0.00453234,
#   'roberta_neu': 0.014126607,
#   'roberta_pos': 0.981341},
#  30: {'vader_neg': 0.017,
#   'vader_neu': 0.846,
#   'vader_pos': 0.137,
#   'vader_compound': 0.9746,
#   'roberta_neg': 0.01913407,
#   'roberta_neu': 0.07104432,
#   'roberta_pos': 0.9098216},
#  31: {'vader_neg': 0.041,
#   'vader_neu': 0.692,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9713,
#   'roberta_neg': 0.0024305154,
#   'roberta_neu': 0.016508143,
#   'roberta_pos': 0.98106134},
#  32: {'vader_neg': 0.0,
#   'vader_neu': 0.484,
#   'vader_pos': 0.516,
#   'vader_compound': 0.9153,
#   'roberta_neg': 0.0013848734,
#   'roberta_neu': 0.009927855,
#   'roberta_pos': 0.9886873},
#  33: {'vader_neg': 0.069,
#   'vader_neu': 0.839,
#   'vader_pos': 0.092,
#   'vader_compound': 0.7103,
#   'roberta_neg': 0.11853353,
#   'roberta_neu': 0.3294422,
#   'roberta_pos': 0.55202425},
#  34: {'vader_neg': 0.024,
#   'vader_neu': 0.72,
#   'vader_pos': 0.256,
#   'vader_compound': 0.9779,
#   'roberta_neg': 0.0049691456,
#   'roberta_neu': 0.051026467,
#   'roberta_pos': 0.94400436},
#  35: {'vader_neg': 0.0,
#   'vader_neu': 0.874,
#   'vader_pos': 0.126,
#   'vader_compound': 0.9091,
#   'roberta_neg': 0.0021597573,
#   'roberta_neu': 0.01779364,
#   'roberta_pos': 0.98004663},
#  36: {'vader_neg': 0.024,
#   'vader_neu': 0.821,
#   'vader_pos': 0.155,
#   'vader_compound': 0.7622,
#   'roberta_neg': 0.0030508486,
#   'roberta_neu': 0.08110079,
#   'roberta_pos': 0.9158484},
#  37: {'vader_neg': 0.0,
#   'vader_neu': 0.754,
#   'vader_pos': 0.246,
#   'vader_compound': 0.9196,
#   'roberta_neg': 0.0024345736,
#   'roberta_neu': 0.011576179,
#   'roberta_pos': 0.9859892},
#  38: {'vader_neg': 0.0,
#   'vader_neu': 0.938,
#   'vader_pos': 0.062,
#   'vader_compound': 0.4457,
#   'roberta_neg': 0.03896906,
#   'roberta_neu': 0.22200035,
#   'roberta_pos': 0.7390306},
#  39: {'vader_neg': 0.05,
#   'vader_neu': 0.846,
#   'vader_pos': 0.104,
#   'vader_compound': 0.7638,
#   'roberta_neg': 0.014056202,
#   'roberta_neu': 0.29882953,
#   'roberta_pos': 0.6871143},
#  40: {'vader_neg': 0.0,
#   'vader_neu': 0.856,
#   'vader_pos': 0.144,
#   'vader_compound': 0.8114,
#   'roberta_neg': 0.0012026605,
#   'roberta_neu': 0.023010882,
#   'roberta_pos': 0.97578645},
#  41: {'vader_neg': 0.033,
#   'vader_neu': 0.82,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9301,
#   'roberta_neg': 0.0096905595,
#   'roberta_neu': 0.03783318,
#   'roberta_pos': 0.95247626},
#  42: {'vader_neg': 0.03,
#   'vader_neu': 0.848,
#   'vader_pos': 0.122,
#   'vader_compound': 0.9435,
#   'roberta_neg': 0.036511745,
#   'roberta_neu': 0.18096739,
#   'roberta_pos': 0.7825209},
#  43: {'vader_neg': 0.0,
#   'vader_neu': 0.588,
#   'vader_pos': 0.412,
#   'vader_compound': 0.9441,
#   'roberta_neg': 0.0014039391,
#   'roberta_neu': 0.009315231,
#   'roberta_pos': 0.9892809},
#  44: {'vader_neg': 0.0,
#   'vader_neu': 0.685,
#   'vader_pos': 0.315,
#   'vader_compound': 0.9161,
#   'roberta_neg': 0.0019128748,
#   'roberta_neu': 0.016714554,
#   'roberta_pos': 0.9813726},
#  45: {'vader_neg': 0.031,
#   'vader_neu': 0.778,
#   'vader_pos': 0.191,
#   'vader_compound': 0.8421,
#   'roberta_neg': 0.005844251,
#   'roberta_neu': 0.041151904,
#   'roberta_pos': 0.9530039},
#  46: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.8868877,
#   'roberta_neu': 0.09925434,
#   'roberta_pos': 0.013857945},
#  47: {'vader_neg': 0.0,
#   'vader_neu': 0.737,
#   'vader_pos': 0.263,
#   'vader_compound': 0.9169,
#   'roberta_neg': 0.100343995,
#   'roberta_neu': 0.295504,
#   'roberta_pos': 0.60415196},
#  48: {'vader_neg': 0.0,
#   'vader_neu': 0.868,
#   'vader_pos': 0.132,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.16032876,
#   'roberta_neu': 0.3389701,
#   'roberta_pos': 0.5007011},
#  49: {'vader_neg': 0.0,
#   'vader_neu': 0.821,
#   'vader_pos': 0.179,
#   'vader_compound': 0.747,
#   'roberta_neg': 0.003388437,
#   'roberta_neu': 0.021274421,
#   'roberta_pos': 0.9753372},
#  50: {'vader_neg': 0.056,
#   'vader_neu': 0.865,
#   'vader_pos': 0.079,
#   'vader_compound': 0.2363,
#   'roberta_neg': 0.90213436,
#   'roberta_neu': 0.08792557,
#   'roberta_pos': 0.00994011},
#  51: {'vader_neg': 0.22,
#   'vader_neu': 0.78,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5448,
#   'roberta_neg': 0.97635514,
#   'roberta_neu': 0.020687463,
#   'roberta_pos': 0.0029573694},
#  52: {'vader_neg': 0.047,
#   'vader_neu': 0.735,
#   'vader_pos': 0.218,
#   'vader_compound': 0.9194,
#   'roberta_neg': 0.004793733,
#   'roberta_neu': 0.026924016,
#   'roberta_pos': 0.9682823},
#  53: {'vader_neg': 0.09,
#   'vader_neu': 0.858,
#   'vader_pos': 0.052,
#   'vader_compound': -0.8259,
#   'roberta_neg': 0.5248544,
#   'roberta_neu': 0.3791848,
#   'roberta_pos': 0.095960744},
#  54: {'vader_neg': 0.075,
#   'vader_neu': 0.925,
#   'vader_pos': 0.0,
#   'vader_compound': -0.3612,
#   'roberta_neg': 0.42265806,
#   'roberta_neu': 0.50050455,
#   'roberta_pos': 0.07683737},
#  55: {'vader_neg': 0.0,
#   'vader_neu': 0.857,
#   'vader_pos': 0.143,
#   'vader_compound': 0.8761,
#   'roberta_neg': 0.0016398341,
#   'roberta_neu': 0.050242238,
#   'roberta_pos': 0.9481179},
#  56: {'vader_neg': 0.071,
#   'vader_neu': 0.708,
#   'vader_pos': 0.221,
#   'vader_compound': 0.8908,
#   'roberta_neg': 0.00180009,
#   'roberta_neu': 0.018932318,
#   'roberta_pos': 0.9792676},
#  57: {'vader_neg': 0.029,
#   'vader_neu': 0.694,
#   'vader_pos': 0.277,
#   'vader_compound': 0.908,
#   'roberta_neg': 0.0016082082,
#   'roberta_neu': 0.008115818,
#   'roberta_pos': 0.990276},
#  58: {'vader_neg': 0.0,
#   'vader_neu': 0.701,
#   'vader_pos': 0.299,
#   'vader_compound': 0.91,
#   'roberta_neg': 0.0020191881,
#   'roberta_neu': 0.01869797,
#   'roberta_pos': 0.9792828},
#  59: {'vader_neg': 0.0,
#   'vader_neu': 0.611,
#   'vader_pos': 0.389,
#   'vader_compound': 0.9323,
#   'roberta_neg': 0.0012205162,
#   'roberta_neu': 0.0077877063,
#   'roberta_pos': 0.99099183},
#  60: {'vader_neg': 0.0,
#   'vader_neu': 0.638,
#   'vader_pos': 0.362,
#   'vader_compound': 0.8807,
#   'roberta_neg': 0.0038701806,
#   'roberta_neu': 0.081627,
#   'roberta_pos': 0.9145028},
#  61: {'vader_neg': 0.0,
#   'vader_neu': 0.9,
#   'vader_pos': 0.1,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.014716534,
#   'roberta_neu': 0.27715138,
#   'roberta_pos': 0.708132},
#  62: {'vader_neg': 0.0,
#   'vader_neu': 0.741,
#   'vader_pos': 0.259,
#   'vader_compound': 0.8442,
#   'roberta_neg': 0.017847514,
#   'roberta_neu': 0.0959161,
#   'roberta_pos': 0.8862363},
#  63: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.9050874,
#   'roberta_neu': 0.082814746,
#   'roberta_pos': 0.012097796},
#  64: {'vader_neg': 0.055,
#   'vader_neu': 0.765,
#   'vader_pos': 0.179,
#   'vader_compound': 0.9817,
#   'roberta_neg': 0.013532361,
#   'roberta_neu': 0.07057338,
#   'roberta_pos': 0.91589427},
#  65: {'vader_neg': 0.046,
#   'vader_neu': 0.75,
#   'vader_pos': 0.205,
#   'vader_compound': 0.8674,
#   'roberta_neg': 0.0015688144,
#   'roberta_neu': 0.018417561,
#   'roberta_pos': 0.9800136},
#  66: {'vader_neg': 0.04,
#   'vader_neu': 0.822,
#   'vader_pos': 0.138,
#   'vader_compound': 0.5165,
#   'roberta_neg': 0.0031999762,
#   'roberta_neu': 0.080463395,
#   'roberta_pos': 0.9163366},
#  67: {'vader_neg': 0.057,
#   'vader_neu': 0.869,
#   'vader_pos': 0.073,
#   'vader_compound': 0.492,
#   'roberta_neg': 0.13516115,
#   'roberta_neu': 0.40439168,
#   'roberta_pos': 0.46044716},
#  68: {'vader_neg': 0.183,
#   'vader_neu': 0.776,
#   'vader_pos': 0.041,
#   'vader_compound': -0.9116,
#   'roberta_neg': 0.87971437,
#   'roberta_neu': 0.10624973,
#   'roberta_pos': 0.014035907},
#  69: {'vader_neg': 0.135,
#   'vader_neu': 0.71,
#   'vader_pos': 0.155,
#   'vader_compound': -0.0096,
#   'roberta_neg': 0.3505018,
#   'roberta_neu': 0.3683784,
#   'roberta_pos': 0.28111982},
#  70: {'vader_neg': 0.344,
#   'vader_neu': 0.52,
#   'vader_pos': 0.136,
#   'vader_compound': -0.7345,
#   'roberta_neg': 0.96015793,
#   'roberta_neu': 0.035429046,
#   'roberta_pos': 0.004412958},
#  71: {'vader_neg': 0.036,
#   'vader_neu': 0.916,
#   'vader_pos': 0.048,
#   'vader_compound': 0.2228,
#   'roberta_neg': 0.032239717,
#   'roberta_neu': 0.1391605,
#   'roberta_pos': 0.82859975},
#  72: {'vader_neg': 0.078,
#   'vader_neu': 0.701,
#   'vader_pos': 0.222,
#   'vader_compound': 0.9733,
#   'roberta_neg': 0.0038743336,
#   'roberta_neu': 0.022212027,
#   'roberta_pos': 0.9739136},
#  73: {'vader_neg': 0.025,
#   'vader_neu': 0.653,
#   'vader_pos': 0.323,
#   'vader_compound': 0.9787,
#   'roberta_neg': 0.0013178965,
#   'roberta_neu': 0.010000751,
#   'roberta_pos': 0.9886813},
#  74: {'vader_neg': 0.093,
#   'vader_neu': 0.762,
#   'vader_pos': 0.144,
#   'vader_compound': 0.9665,
#   'roberta_neg': 0.54130054,
#   'roberta_neu': 0.30490556,
#   'roberta_pos': 0.15379392},
#  75: {'vader_neg': 0.0,
#   'vader_neu': 0.872,
#   'vader_pos': 0.128,
#   'vader_compound': 0.2263,
#   'roberta_neg': 0.13885973,
#   'roberta_neu': 0.53205615,
#   'roberta_pos': 0.3290841},
#  76: {'vader_neg': 0.106,
#   'vader_neu': 0.768,
#   'vader_pos': 0.126,
#   'vader_compound': 0.1098,
#   'roberta_neg': 0.9441382,
#   'roberta_neu': 0.050168023,
#   'roberta_pos': 0.005693684},
#  77: {'vader_neg': 0.019,
#   'vader_neu': 0.898,
#   'vader_pos': 0.083,
#   'vader_compound': 0.5647,
#   'roberta_neg': 0.26665485,
#   'roberta_neu': 0.43165025,
#   'roberta_pos': 0.30169496},
#  78: {'vader_neg': 0.034,
#   'vader_neu': 0.798,
#   'vader_pos': 0.168,
#   'vader_compound': 0.8303,
#   'roberta_neg': 0.0035588227,
#   'roberta_neu': 0.027854534,
#   'roberta_pos': 0.9685866},
#  79: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.7814,
#   'roberta_neg': 0.0048486483,
#   'roberta_neu': 0.052556068,
#   'roberta_pos': 0.9425953},
#  80: {'vader_neg': 0.087,
#   'vader_neu': 0.589,
#   'vader_pos': 0.324,
#   'vader_compound': 0.8636,
#   'roberta_neg': 0.6261532,
#   'roberta_neu': 0.28211513,
#   'roberta_pos': 0.0917317},
#  81: {'vader_neg': 0.0,
#   'vader_neu': 0.723,
#   'vader_pos': 0.277,
#   'vader_compound': 0.9098,
#   'roberta_neg': 0.0015721095,
#   'roberta_neu': 0.0062695034,
#   'roberta_pos': 0.9921584},
#  82: {'vader_neg': 0.0,
#   'vader_neu': 0.663,
#   'vader_pos': 0.337,
#   'vader_compound': 0.9041,
#   'roberta_neg': 0.0025260567,
#   'roberta_neu': 0.012215312,
#   'roberta_pos': 0.9852586},
#  84: {'vader_neg': 0.055,
#   'vader_neu': 0.767,
#   'vader_pos': 0.178,
#   'vader_compound': 0.8642,
#   'roberta_neg': 0.102506384,
#   'roberta_neu': 0.40360445,
#   'roberta_pos': 0.49388912},
#  85: {'vader_neg': 0.109,
#   'vader_neu': 0.676,
#   'vader_pos': 0.214,
#   'vader_compound': 0.8431,
#   'roberta_neg': 0.12168527,
#   'roberta_neu': 0.35795102,
#   'roberta_pos': 0.52036375},
#  86: {'vader_neg': 0.035,
#   'vader_neu': 0.698,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9487,
#   'roberta_neg': 0.0024510382,
#   'roberta_neu': 0.010034804,
#   'roberta_pos': 0.9875142},
#  87: {'vader_neg': 0.019,
#   'vader_neu': 0.855,
#   'vader_pos': 0.126,
#   'vader_compound': 0.8797,
#   'roberta_neg': 0.036023285,
#   'roberta_neu': 0.14819308,
#   'roberta_pos': 0.8157837},
#  88: {'vader_neg': 0.05,
#   'vader_neu': 0.735,
#   'vader_pos': 0.215,
#   'vader_compound': 0.7424,
#   'roberta_neg': 0.0051310207,
#   'roberta_neu': 0.04044685,
#   'roberta_pos': 0.9544221},
#  89: {'vader_neg': 0.048,
#   'vader_neu': 0.762,
#   'vader_pos': 0.19,
#   'vader_compound': 0.9716,
#   'roberta_neg': 0.016248997,
#   'roberta_neu': 0.10783319,
#   'roberta_pos': 0.8759178},
#  90: {'vader_neg': 0.029,
#   'vader_neu': 0.645,
#   'vader_pos': 0.326,
#   'vader_compound': 0.9554,
#   'roberta_neg': 0.0036095025,
#   'roberta_neu': 0.00985429,
#   'roberta_pos': 0.9865362},
#  91: {'vader_neg': 0.0,
#   'vader_neu': 0.833,
#   'vader_pos': 0.167,
#   'vader_compound': 0.7351,
#   'roberta_neg': 0.009687848,
#   'roberta_neu': 0.13429165,
#   'roberta_pos': 0.8560205},
#  92: {'vader_neg': 0.0,
#   'vader_neu': 0.837,
#   'vader_pos': 0.163,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.007930281,
#   'roberta_neu': 0.044241518,
#   'roberta_pos': 0.94782823},
#  93: {'vader_neg': 0.069,
#   'vader_neu': 0.663,
#   'vader_pos': 0.268,
#   'vader_compound': 0.8255,
#   'roberta_neg': 0.0022618964,
#   'roberta_neu': 0.00767613,
#   'roberta_pos': 0.990062},
#  94: {'vader_neg': 0.01,
#   'vader_neu': 0.781,
#   'vader_pos': 0.208,
#   'vader_compound': 0.9882,
#   'roberta_neg': 0.008068764,
#   'roberta_neu': 0.054976303,
#   'roberta_pos': 0.9369549},
#  95: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.021683812,
#   'roberta_neu': 0.4229408,
#   'roberta_pos': 0.5553754},
#  96: {'vader_neg': 0.031,
#   'vader_neu': 0.732,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9273,
#   'roberta_neg': 0.007116635,
#   'roberta_neu': 0.06120496,
#   'roberta_pos': 0.9316784},
#  97: {'vader_neg': 0.0,
#   'vader_neu': 0.818,
#   'vader_pos': 0.182,
#   'vader_compound': 0.982,
#   'roberta_neg': 0.0030773,
#   'roberta_neu': 0.03615042,
#   'roberta_pos': 0.9607722},
#  98: {'vader_neg': 0.053,
#   'vader_neu': 0.793,
#   'vader_pos': 0.154,
#   'vader_compound': 0.7729,
#   'roberta_neg': 0.15611698,
#   'roberta_neu': 0.30707535,
#   'roberta_pos': 0.53680766},
#  99: {'vader_neg': 0.024,
#   'vader_neu': 0.91,
#   'vader_pos': 0.066,
#   'vader_compound': 0.5106,
#   'roberta_neg': 0.09271855,
#   'roberta_neu': 0.5976606,
#   'roberta_pos': 0.3096209},
#  100: {'vader_neg': 0.173,
#   'vader_neu': 0.735,
#   'vader_pos': 0.092,
#   'vader_compound': -0.5267,
#   'roberta_neg': 0.9624427,
#   'roberta_neu': 0.03197863,
#   'roberta_pos': 0.005578707},
#  101: {'vader_neg': 0.0,
#   'vader_neu': 0.807,
#   'vader_pos': 0.193,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.3069215,
#   'roberta_neu': 0.45656905,
#   'roberta_pos': 0.23650944},
#  102: {'vader_neg': 0.103,
#   'vader_neu': 0.752,
#   'vader_pos': 0.145,
#   'vader_compound': 0.2285,
#   'roberta_neg': 0.06290266,
#   'roberta_neu': 0.29451638,
#   'roberta_pos': 0.6425809},
#  103: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9287,
#   'roberta_neg': 0.040520415,
#   'roberta_neu': 0.110866256,
#   'roberta_pos': 0.8486133},
#  104: {'vader_neg': 0.0,
#   'vader_neu': 0.859,
#   'vader_pos': 0.141,
#   'vader_compound': 0.7249,
#   'roberta_neg': 0.029932478,
#   'roberta_neu': 0.05488074,
#   'roberta_pos': 0.9151868},
#  105: {'vader_neg': 0.051,
#   'vader_neu': 0.577,
#   'vader_pos': 0.372,
#   'vader_compound': 0.9313,
#   'roberta_neg': 0.0038570892,
#   'roberta_neu': 0.013474414,
#   'roberta_pos': 0.9826685},
#  106: {'vader_neg': 0.0,
#   'vader_neu': 0.696,
#   'vader_pos': 0.304,
#   'vader_compound': 0.9603,
#   'roberta_neg': 0.0018723512,
#   'roberta_neu': 0.008443224,
#   'roberta_pos': 0.98968446},
#  107: {'vader_neg': 0.0,
#   'vader_neu': 0.791,
#   'vader_pos': 0.209,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.36725077,
#   'roberta_neu': 0.43870354,
#   'roberta_pos': 0.19404577},
#  108: {'vader_neg': 0.0,
#   'vader_neu': 0.804,
#   'vader_pos': 0.196,
#   'vader_compound': 0.9503,
#   'roberta_neg': 0.0019238472,
#   'roberta_neu': 0.016131027,
#   'roberta_pos': 0.98194516},
#  109: {'vader_neg': 0.059,
#   'vader_neu': 0.676,
#   'vader_pos': 0.265,
#   'vader_compound': 0.9116,
#   'roberta_neg': 0.0024852508,
#   'roberta_neu': 0.00586961,
#   'roberta_pos': 0.99164516},
#  110: {'vader_neg': 0.014,
#   'vader_neu': 0.764,
#   'vader_pos': 0.222,
#   'vader_compound': 0.9841,
#   'roberta_neg': 0.0024270825,
#   'roberta_neu': 0.01181351,
#   'roberta_pos': 0.98575944},
#  111: {'vader_neg': 0.059,
#   'vader_neu': 0.879,
#   'vader_pos': 0.062,
#   'vader_compound': 0.0176,
#   'roberta_neg': 0.0710357,
#   'roberta_neu': 0.4062136,
#   'roberta_pos': 0.52275074},
#  112: {'vader_neg': 0.0,
#   'vader_neu': 0.81,
#   'vader_pos': 0.19,
#   'vader_compound': 0.8769,
#   'roberta_neg': 0.0038921316,
#   'roberta_neu': 0.021213945,
#   'roberta_pos': 0.97489387},
#  113: {'vader_neg': 0.037,
#   'vader_neu': 0.786,
#   'vader_pos': 0.177,
#   'vader_compound': 0.9946,
#   'roberta_neg': 0.11883129,
#   'roberta_neu': 0.38704342,
#   'roberta_pos': 0.4941253},
#  114: {'vader_neg': 0.0,
#   'vader_neu': 0.631,
#   'vader_pos': 0.369,
#   'vader_compound': 0.8779,
#   'roberta_neg': 0.0019037203,
#   'roberta_neu': 0.009111729,
#   'roberta_pos': 0.98898447},
#  115: {'vader_neg': 0.027,
#   'vader_neu': 0.727,
#   'vader_pos': 0.245,
#   'vader_compound': 0.9379,
#   'roberta_neg': 0.003750973,
#   'roberta_neu': 0.012069862,
#   'roberta_pos': 0.9841792},
#  116: {'vader_neg': 0.0,
#   'vader_neu': 0.645,
#   'vader_pos': 0.355,
#   'vader_compound': 0.872,
#   'roberta_neg': 0.0012511908,
#   'roberta_neu': 0.016081374,
#   'roberta_pos': 0.9826674},
#  117: {'vader_neg': 0.0,
#   'vader_neu': 0.892,
#   'vader_pos': 0.108,
#   'vader_compound': 0.6573,
#   'roberta_neg': 0.0034060208,
#   'roberta_neu': 0.03961202,
#   'roberta_pos': 0.95698196},
#  118: {'vader_neg': 0.0,
#   'vader_neu': 0.781,
#   'vader_pos': 0.219,
#   'vader_compound': 0.9751,
#   'roberta_neg': 0.0017548684,
#   'roberta_neu': 0.01014398,
#   'roberta_pos': 0.9881011},
#  119: {'vader_neg': 0.05,
#   'vader_neu': 0.872,
#   'vader_pos': 0.079,
#   'vader_compound': 0.8972,
#   'roberta_neg': 0.28056335,
#   'roberta_neu': 0.47737712,
#   'roberta_pos': 0.24205948},
#  120: {'vader_neg': 0.013,
#   'vader_neu': 0.785,
#   'vader_pos': 0.203,
#   'vader_compound': 0.9828,
#   'roberta_neg': 0.0032583724,
#   'roberta_neu': 0.018432477,
#   'roberta_pos': 0.9783092},
#  121: {'vader_neg': 0.026,
#   'vader_neu': 0.759,
#   'vader_pos': 0.215,
#   'vader_compound': 0.9509,
#   'roberta_neg': 0.0035531821,
#   'roberta_neu': 0.022996048,
#   'roberta_pos': 0.9734508},
#  122: {'vader_neg': 0.102,
#   'vader_neu': 0.822,
#   'vader_pos': 0.076,
#   'vader_compound': -0.3626,
#   'roberta_neg': 0.19982728,
#   'roberta_neu': 0.46116292,
#   'roberta_pos': 0.33900976},
#  123: {'vader_neg': 0.025,
#   'vader_neu': 0.803,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9022,
#   'roberta_neg': 0.13655333,
#   'roberta_neu': 0.34716138,
#   'roberta_pos': 0.5162853},
#  124: {'vader_neg': 0.017,
#   'vader_neu': 0.795,
#   'vader_pos': 0.188,
#   'vader_compound': 0.9769,
#   'roberta_neg': 0.08452791,
#   'roberta_neu': 0.39469165,
#   'roberta_pos': 0.5207805},
#  125: {'vader_neg': 0.079,
#   'vader_neu': 0.67,
#   'vader_pos': 0.252,
#   'vader_compound': 0.9678,
#   'roberta_neg': 0.004302054,
#   'roberta_neu': 0.02723526,
#   'roberta_pos': 0.9684627},
#  126: {'vader_neg': 0.035,
#   'vader_neu': 0.87,
#   'vader_pos': 0.095,
#   'vader_compound': 0.5709,
#   'roberta_neg': 0.023989355,
#   'roberta_neu': 0.18277088,
#   'roberta_pos': 0.7932398},
#  127: {'vader_neg': 0.0,
#   'vader_neu': 0.721,
#   'vader_pos': 0.279,
#   'vader_compound': 0.9258,
#   'roberta_neg': 0.0015730262,
#   'roberta_neu': 0.014196356,
#   'roberta_pos': 0.9842306},
#  128: {'vader_neg': 0.067,
#   'vader_neu': 0.633,
#   'vader_pos': 0.299,
#   'vader_compound': 0.9022,
#   'roberta_neg': 0.0077698687,
#   'roberta_neu': 0.04948701,
#   'roberta_pos': 0.9427432},
#  129: {'vader_neg': 0.043,
#   'vader_neu': 0.728,
#   'vader_pos': 0.229,
#   'vader_compound': 0.8142,
#   'roberta_neg': 0.00250572,
#   'roberta_neu': 0.013060367,
#   'roberta_pos': 0.9844338},
#  130: {'vader_neg': 0.114,
#   'vader_neu': 0.676,
#   'vader_pos': 0.21,
#   'vader_compound': 0.6721,
#   'roberta_neg': 0.58715963,
#   'roberta_neu': 0.26330015,
#   'roberta_pos': 0.14954022},
#  131: {'vader_neg': 0.0,
#   'vader_neu': 0.755,
#   'vader_pos': 0.245,
#   'vader_compound': 0.8658,
#   'roberta_neg': 0.001669051,
#   'roberta_neu': 0.016341796,
#   'roberta_pos': 0.98198915},
#  132: {'vader_neg': 0.135,
#   'vader_neu': 0.76,
#   'vader_pos': 0.105,
#   'vader_compound': -0.3612,
#   'roberta_neg': 0.74938285,
#   'roberta_neu': 0.2226979,
#   'roberta_pos': 0.027919307},
#  133: {'vader_neg': 0.046,
#   'vader_neu': 0.772,
#   'vader_pos': 0.181,
#   'vader_compound': 0.7902,
#   'roberta_neg': 0.08118547,
#   'roberta_neu': 0.19308396,
#   'roberta_pos': 0.7257306},
#  134: {'vader_neg': 0.02,
#   'vader_neu': 0.878,
#   'vader_pos': 0.103,
#   'vader_compound': 0.8082,
#   'roberta_neg': 0.0017438803,
#   'roberta_neu': 0.013367518,
#   'roberta_pos': 0.98488855},
#  135: {'vader_neg': 0.0,
#   'vader_neu': 0.877,
#   'vader_pos': 0.123,
#   'vader_compound': 0.4215,
#   'roberta_neg': 0.0010293368,
#   'roberta_neu': 0.026390305,
#   'roberta_pos': 0.9725804},
#  136: {'vader_neg': 0.0,
#   'vader_neu': 0.9,
#   'vader_pos': 0.1,
#   'vader_compound': 0.6503,
#   'roberta_neg': 0.02364978,
#   'roberta_neu': 0.057855014,
#   'roberta_pos': 0.9184952},
#  137: {'vader_neg': 0.0,
#   'vader_neu': 0.695,
#   'vader_pos': 0.305,
#   'vader_compound': 0.9661,
#   'roberta_neg': 0.0014717452,
#   'roberta_neu': 0.011302728,
#   'roberta_pos': 0.9872255},
#  138: {'vader_neg': 0.0,
#   'vader_neu': 0.689,
#   'vader_pos': 0.311,
#   'vader_compound': 0.8591,
#   'roberta_neg': 0.024912076,
#   'roberta_neu': 0.103373185,
#   'roberta_pos': 0.87171465},
#  139: {'vader_neg': 0.15,
#   'vader_neu': 0.773,
#   'vader_pos': 0.077,
#   'vader_compound': -0.4199,
#   'roberta_neg': 0.15639952,
#   'roberta_neu': 0.24645051,
#   'roberta_pos': 0.59715},
#  140: {'vader_neg': 0.043,
#   'vader_neu': 0.833,
#   'vader_pos': 0.125,
#   'vader_compound': 0.835,
#   'roberta_neg': 0.024401577,
#   'roberta_neu': 0.07160529,
#   'roberta_pos': 0.9039931},
#  141: {'vader_neg': 0.098,
#   'vader_neu': 0.787,
#   'vader_pos': 0.114,
#   'vader_compound': 0.2023,
#   'roberta_neg': 0.24081118,
#   'roberta_neu': 0.43190494,
#   'roberta_pos': 0.32728386},
#  142: {'vader_neg': 0.0,
#   'vader_neu': 0.782,
#   'vader_pos': 0.218,
#   'vader_compound': 0.7814,
#   'roberta_neg': 0.01640072,
#   'roberta_neu': 0.08700863,
#   'roberta_pos': 0.89659065},
#  143: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9296,
#   'roberta_neg': 0.0025163018,
#   'roberta_neu': 0.007232636,
#   'roberta_pos': 0.99025106},
#  144: {'vader_neg': 0.059,
#   'vader_neu': 0.667,
#   'vader_pos': 0.274,
#   'vader_compound': 0.9653,
#   'roberta_neg': 0.0021510748,
#   'roberta_neu': 0.011133499,
#   'roberta_pos': 0.9867155},
#  145: {'vader_neg': 0.058,
#   'vader_neu': 0.841,
#   'vader_pos': 0.102,
#   'vader_compound': 0.6124,
#   'roberta_neg': 0.5052256,
#   'roberta_neu': 0.4370697,
#   'roberta_pos': 0.05770471},
#  146: {'vader_neg': 0.144,
#   'vader_neu': 0.677,
#   'vader_pos': 0.178,
#   'vader_compound': 0.6341,
#   'roberta_neg': 0.0051465803,
#   'roberta_neu': 0.03438664,
#   'roberta_pos': 0.96046674},
#  147: {'vader_neg': 0.087,
#   'vader_neu': 0.783,
#   'vader_pos': 0.13,
#   'vader_compound': 0.7567,
#   'roberta_neg': 0.3634237,
#   'roberta_neu': 0.41858402,
#   'roberta_pos': 0.21799229},
#  148: {'vader_neg': 0.058,
#   'vader_neu': 0.867,
#   'vader_pos': 0.075,
#   'vader_compound': 0.1533,
#   'roberta_neg': 0.055790234,
#   'roberta_neu': 0.12982295,
#   'roberta_pos': 0.81438684},
#  149: {'vader_neg': 0.04,
#   'vader_neu': 0.833,
#   'vader_pos': 0.127,
#   'vader_compound': 0.6956,
#   'roberta_neg': 0.044037797,
#   'roberta_neu': 0.18290451,
#   'roberta_pos': 0.77305764},
#  150: {'vader_neg': 0.0,
#   'vader_neu': 0.709,
#   'vader_pos': 0.291,
#   'vader_compound': 0.9231,
#   'roberta_neg': 0.001293348,
#   'roberta_neu': 0.013132086,
#   'roberta_pos': 0.9855746},
#  151: {'vader_neg': 0.0,
#   'vader_neu': 0.564,
#   'vader_pos': 0.436,
#   'vader_compound': 0.9858,
#   'roberta_neg': 0.0015664415,
#   'roberta_neu': 0.0068320893,
#   'roberta_pos': 0.9916014},
#  152: {'vader_neg': 0.0,
#   'vader_neu': 0.784,
#   'vader_pos': 0.216,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.002013052,
#   'roberta_neu': 0.062400118,
#   'roberta_pos': 0.9355868},
#  153: {'vader_neg': 0.0,
#   'vader_neu': 0.775,
#   'vader_pos': 0.225,
#   'vader_compound': 0.7269,
#   'roberta_neg': 0.0013454015,
#   'roberta_neu': 0.02719141,
#   'roberta_pos': 0.9714632},
#  154: {'vader_neg': 0.12,
#   'vader_neu': 0.76,
#   'vader_pos': 0.12,
#   'vader_compound': 0.2502,
#   'roberta_neg': 0.70836955,
#   'roberta_neu': 0.23563293,
#   'roberta_pos': 0.055997483},
#  155: {'vader_neg': 0.0,
#   'vader_neu': 0.647,
#   'vader_pos': 0.353,
#   'vader_compound': 0.9803,
#   'roberta_neg': 0.0016300841,
#   'roberta_neu': 0.0053900513,
#   'roberta_pos': 0.99297994},
#  156: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.9681,
#   'roberta_neg': 0.0019889975,
#   'roberta_neu': 0.012380148,
#   'roberta_pos': 0.9856309},
#  157: {'vader_neg': 0.191,
#   'vader_neu': 0.809,
#   'vader_pos': 0.0,
#   'vader_compound': -0.7269,
#   'roberta_neg': 0.022001676,
#   'roberta_neu': 0.16944794,
#   'roberta_pos': 0.80855036},
#  158: {'vader_neg': 0.071,
#   'vader_neu': 0.514,
#   'vader_pos': 0.415,
#   'vader_compound': 0.8934,
#   'roberta_neg': 0.0023668201,
#   'roberta_neu': 0.028503563,
#   'roberta_pos': 0.9691297},
#  159: {'vader_neg': 0.065,
#   'vader_neu': 0.893,
#   'vader_pos': 0.042,
#   'vader_compound': -0.4721,
#   'roberta_neg': 0.1298855,
#   'roberta_neu': 0.32907444,
#   'roberta_pos': 0.54104006},
#  160: {'vader_neg': 0.081,
#   'vader_neu': 0.779,
#   'vader_pos': 0.14,
#   'vader_compound': 0.4194,
#   'roberta_neg': 0.08064926,
#   'roberta_neu': 0.27685288,
#   'roberta_pos': 0.64249784},
#  161: {'vader_neg': 0.0,
#   'vader_neu': 0.644,
#   'vader_pos': 0.356,
#   'vader_compound': 0.9117,
#   'roberta_neg': 0.0012850066,
#   'roberta_neu': 0.010186672,
#   'roberta_pos': 0.9885283},
#  162: {'vader_neg': 0.106,
#   'vader_neu': 0.894,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5504,
#   'roberta_neg': 0.91529846,
#   'roberta_neu': 0.07865338,
#   'roberta_pos': 0.006048219},
#  163: {'vader_neg': 0.072,
#   'vader_neu': 0.652,
#   'vader_pos': 0.276,
#   'vader_compound': 0.9517,
#   'roberta_neg': 0.024918323,
#   'roberta_neu': 0.14422983,
#   'roberta_pos': 0.8308519},
#  164: {'vader_neg': 0.047,
#   'vader_neu': 0.869,
#   'vader_pos': 0.085,
#   'vader_compound': 0.4199,
#   'roberta_neg': 0.0043773274,
#   'roberta_neu': 0.051931076,
#   'roberta_pos': 0.9436916},
#  165: {'vader_neg': 0.025,
#   'vader_neu': 0.752,
#   'vader_pos': 0.223,
#   'vader_compound': 0.8957,
#   'roberta_neg': 0.36830822,
#   'roberta_neu': 0.42519736,
#   'roberta_pos': 0.20649439},
#  166: {'vader_neg': 0.032,
#   'vader_neu': 0.717,
#   'vader_pos': 0.251,
#   'vader_compound': 0.9597,
#   'roberta_neg': 0.001783693,
#   'roberta_neu': 0.017604057,
#   'roberta_pos': 0.9806122},
#  167: {'vader_neg': 0.0,
#   'vader_neu': 0.657,
#   'vader_pos': 0.343,
#   'vader_compound': 0.9098,
#   'roberta_neg': 0.0016492166,
#   'roberta_neu': 0.0281265,
#   'roberta_pos': 0.9702243},
#  168: {'vader_neg': 0.05,
#   'vader_neu': 0.905,
#   'vader_pos': 0.045,
#   'vader_compound': -0.1154,
#   'roberta_neg': 0.9482189,
#   'roberta_neu': 0.046903588,
#   'roberta_pos': 0.004877555},
#  169: {'vader_neg': 0.186,
#   'vader_neu': 0.74,
#   'vader_pos': 0.074,
#   'vader_compound': -0.5283,
#   'roberta_neg': 0.9343901,
#   'roberta_neu': 0.05704221,
#   'roberta_pos': 0.008567603},
#  170: {'vader_neg': 0.141,
#   'vader_neu': 0.832,
#   'vader_pos': 0.028,
#   'vader_compound': -0.7721,
#   'roberta_neg': 0.69411093,
#   'roberta_neu': 0.26396132,
#   'roberta_pos': 0.041927814},
#  171: {'vader_neg': 0.0,
#   'vader_neu': 0.854,
#   'vader_pos': 0.146,
#   'vader_compound': 0.6476,
#   'roberta_neg': 0.0017671376,
#   'roberta_neu': 0.05757558,
#   'roberta_pos': 0.9406573},
#  172: {'vader_neg': 0.04,
#   'vader_neu': 0.844,
#   'vader_pos': 0.116,
#   'vader_compound': 0.6808,
#   'roberta_neg': 0.0059573604,
#   'roberta_neu': 0.048739318,
#   'roberta_pos': 0.94530326},
#  173: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.8906,
#   'roberta_neg': 0.0021157113,
#   'roberta_neu': 0.01113412,
#   'roberta_pos': 0.9867502},
#  174: {'vader_neg': 0.022,
#   'vader_neu': 0.788,
#   'vader_pos': 0.189,
#   'vader_compound': 0.9901,
#   'roberta_neg': 0.0049084397,
#   'roberta_neu': 0.048054636,
#   'roberta_pos': 0.9470369},
#  175: {'vader_neg': 0.04,
#   'vader_neu': 0.722,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9782,
#   'roberta_neg': 0.042037666,
#   'roberta_neu': 0.1682309,
#   'roberta_pos': 0.78973144},
#  176: {'vader_neg': 0.0,
#   'vader_neu': 0.874,
#   'vader_pos': 0.126,
#   'vader_compound': 0.7579,
#   'roberta_neg': 0.0014610926,
#   'roberta_neu': 0.017898045,
#   'roberta_pos': 0.9806409},
#  177: {'vader_neg': 0.0,
#   'vader_neu': 0.938,
#   'vader_pos': 0.062,
#   'vader_compound': 0.4215,
#   'roberta_neg': 0.0027336746,
#   'roberta_neu': 0.04397871,
#   'roberta_pos': 0.95328766},
#  178: {'vader_neg': 0.058,
#   'vader_neu': 0.794,
#   'vader_pos': 0.148,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.0331873,
#   'roberta_neu': 0.17210284,
#   'roberta_pos': 0.7947099},
#  179: {'vader_neg': 0.2,
#   'vader_neu': 0.63,
#   'vader_pos': 0.171,
#   'vader_compound': 0.1203,
#   'roberta_neg': 0.062526494,
#   'roberta_neu': 0.183365,
#   'roberta_pos': 0.7541085},
#  180: {'vader_neg': 0.048,
#   'vader_neu': 0.829,
#   'vader_pos': 0.122,
#   'vader_compound': 0.7458,
#   'roberta_neg': 0.011383913,
#   'roberta_neu': 0.054276682,
#   'roberta_pos': 0.93433946},
#  181: {'vader_neg': 0.076,
#   'vader_neu': 0.767,
#   'vader_pos': 0.156,
#   'vader_compound': 0.6085,
#   'roberta_neg': 0.118861176,
#   'roberta_neu': 0.34905016,
#   'roberta_pos': 0.53208864},
#  182: {'vader_neg': 0.0,
#   'vader_neu': 0.433,
#   'vader_pos': 0.567,
#   'vader_compound': 0.9667,
#   'roberta_neg': 0.0018885633,
#   'roberta_neu': 0.007512763,
#   'roberta_pos': 0.99059874},
#  183: {'vader_neg': 0.088,
#   'vader_neu': 0.743,
#   'vader_pos': 0.169,
#   'vader_compound': 0.943,
#   'roberta_neg': 0.02521389,
#   'roberta_neu': 0.10751423,
#   'roberta_pos': 0.86727184},
#  184: {'vader_neg': 0.0,
#   'vader_neu': 0.857,
#   'vader_pos': 0.143,
#   'vader_compound': 0.9577,
#   'roberta_neg': 0.0025648787,
#   'roberta_neu': 0.03025906,
#   'roberta_pos': 0.967176},
#  185: {'vader_neg': 0.11,
#   'vader_neu': 0.593,
#   'vader_pos': 0.297,
#   'vader_compound': 0.6597,
#   'roberta_neg': 0.0019503072,
#   'roberta_neu': 0.012991922,
#   'roberta_pos': 0.9850578},
#  186: {'vader_neg': 0.189,
#   'vader_neu': 0.811,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5994,
#   'roberta_neg': 0.14508067,
#   'roberta_neu': 0.42683965,
#   'roberta_pos': 0.42807975},
#  188: {'vader_neg': 0.0,
#   'vader_neu': 0.824,
#   'vader_pos': 0.176,
#   'vader_compound': 0.6983,
#   'roberta_neg': 0.03735745,
#   'roberta_neu': 0.22594173,
#   'roberta_pos': 0.7367009},
#  189: {'vader_neg': 0.0,
#   'vader_neu': 0.843,
#   'vader_pos': 0.157,
#   'vader_compound': 0.8868,
#   'roberta_neg': 0.0033642177,
#   'roberta_neu': 0.030222995,
#   'roberta_pos': 0.9664128},
#  190: {'vader_neg': 0.0,
#   'vader_neu': 0.934,
#   'vader_pos': 0.066,
#   'vader_compound': 0.3506,
#   'roberta_neg': 0.108292595,
#   'roberta_neu': 0.3163683,
#   'roberta_pos': 0.5753391},
#  191: {'vader_neg': 0.148,
#   'vader_neu': 0.64,
#   'vader_pos': 0.212,
#   'vader_compound': 0.4926,
#   'roberta_neg': 0.0021076459,
#   'roberta_neu': 0.016815946,
#   'roberta_pos': 0.9810765},
#  192: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9062,
#   'roberta_neg': 0.0013114836,
#   'roberta_neu': 0.012644112,
#   'roberta_pos': 0.9860444},
#  193: {'vader_neg': 0.055,
#   'vader_neu': 0.728,
#   'vader_pos': 0.217,
#   'vader_compound': 0.8756,
#   'roberta_neg': 0.030883634,
#   'roberta_neu': 0.055609047,
#   'roberta_pos': 0.91350734},
#  194: {'vader_neg': 0.031,
#   'vader_neu': 0.735,
#   'vader_pos': 0.234,
#   'vader_compound': 0.9595,
#   'roberta_neg': 0.007462463,
#   'roberta_neu': 0.026351862,
#   'roberta_pos': 0.96618575},
#  195: {'vader_neg': 0.082,
#   'vader_neu': 0.483,
#   'vader_pos': 0.435,
#   'vader_compound': 0.8299,
#   'roberta_neg': 0.049120758,
#   'roberta_neu': 0.20355521,
#   'roberta_pos': 0.747324},
#  196: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9538,
#   'roberta_neg': 0.0020688826,
#   'roberta_neu': 0.025906669,
#   'roberta_pos': 0.97202444},
#  197: {'vader_neg': 0.0,
#   'vader_neu': 0.917,
#   'vader_pos': 0.083,
#   'vader_compound': 0.4738,
#   'roberta_neg': 0.06278983,
#   'roberta_neu': 0.30154252,
#   'roberta_pos': 0.6356676},
#  198: {'vader_neg': 0.0,
#   'vader_neu': 0.904,
#   'vader_pos': 0.096,
#   'vader_compound': 0.4153,
#   'roberta_neg': 0.64042616,
#   'roberta_neu': 0.31095317,
#   'roberta_pos': 0.048620652},
#  199: {'vader_neg': 0.0,
#   'vader_neu': 0.701,
#   'vader_pos': 0.299,
#   'vader_compound': 0.8268,
#   'roberta_neg': 0.0010561257,
#   'roberta_neu': 0.018173018,
#   'roberta_pos': 0.9807709},
#  200: {'vader_neg': 0.0,
#   'vader_neu': 0.811,
#   'vader_pos': 0.189,
#   'vader_compound': 0.7178,
#   'roberta_neg': 0.008402119,
#   'roberta_neu': 0.11609159,
#   'roberta_pos': 0.87550634},
#  201: {'vader_neg': 0.039,
#   'vader_neu': 0.888,
#   'vader_pos': 0.072,
#   'vader_compound': 0.6381,
#   'roberta_neg': 0.5752355,
#   'roberta_neu': 0.38917682,
#   'roberta_pos': 0.0355877},
#  202: {'vader_neg': 0.064,
#   'vader_neu': 0.597,
#   'vader_pos': 0.339,
#   'vader_compound': 0.9531,
#   'roberta_neg': 0.006313387,
#   'roberta_neu': 0.035879984,
#   'roberta_pos': 0.9578066},
#  203: {'vader_neg': 0.0,
#   'vader_neu': 0.688,
#   'vader_pos': 0.312,
#   'vader_compound': 0.8225,
#   'roberta_neg': 0.0050344192,
#   'roberta_neu': 0.032026257,
#   'roberta_pos': 0.96293926},
#  204: {'vader_neg': 0.061,
#   'vader_neu': 0.814,
#   'vader_pos': 0.125,
#   'vader_compound': 0.8728,
#   'roberta_neg': 0.13175793,
#   'roberta_neu': 0.39078307,
#   'roberta_pos': 0.47745895},
#  205: {'vader_neg': 0.0,
#   'vader_neu': 0.882,
#   'vader_pos': 0.118,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.0021677339,
#   'roberta_neu': 0.011405092,
#   'roberta_pos': 0.9864271},
#  206: {'vader_neg': 0.0,
#   'vader_neu': 0.754,
#   'vader_pos': 0.246,
#   'vader_compound': 0.9368,
#   'roberta_neg': 0.0017023458,
#   'roberta_neu': 0.006947412,
#   'roberta_pos': 0.9913502},
#  207: {'vader_neg': 0.0,
#   'vader_neu': 0.59,
#   'vader_pos': 0.41,
#   'vader_compound': 0.8779,
#   'roberta_neg': 0.0030471298,
#   'roberta_neu': 0.0323657,
#   'roberta_pos': 0.9645872},
#  208: {'vader_neg': 0.051,
#   'vader_neu': 0.8,
#   'vader_pos': 0.15,
#   'vader_compound': 0.8436,
#   'roberta_neg': 0.0048194123,
#   'roberta_neu': 0.04611087,
#   'roberta_pos': 0.94906974},
#  209: {'vader_neg': 0.05,
#   'vader_neu': 0.82,
#   'vader_pos': 0.13,
#   'vader_compound': 0.8913,
#   'roberta_neg': 0.09590432,
#   'roberta_neu': 0.28223923,
#   'roberta_pos': 0.6218564},
#  210: {'vader_neg': 0.045,
#   'vader_neu': 0.761,
#   'vader_pos': 0.194,
#   'vader_compound': 0.9893,
#   'roberta_neg': 0.013688032,
#   'roberta_neu': 0.11643518,
#   'roberta_pos': 0.8698768},
#  211: {'vader_neg': 0.075,
#   'vader_neu': 0.755,
#   'vader_pos': 0.171,
#   'vader_compound': 0.9218,
#   'roberta_neg': 0.017106287,
#   'roberta_neu': 0.09481569,
#   'roberta_pos': 0.888078},
#  212: {'vader_neg': 0.051,
#   'vader_neu': 0.821,
#   'vader_pos': 0.129,
#   'vader_compound': 0.9529,
#   'roberta_neg': 0.022888804,
#   'roberta_neu': 0.2371116,
#   'roberta_pos': 0.7399996},
#  213: {'vader_neg': 0.051,
#   'vader_neu': 0.838,
#   'vader_pos': 0.11,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.6926146,
#   'roberta_neu': 0.2631969,
#   'roberta_pos': 0.044188466},
#  214: {'vader_neg': 0.095,
#   'vader_neu': 0.883,
#   'vader_pos': 0.022,
#   'vader_compound': -0.9726,
#   'roberta_neg': 0.7607974,
#   'roberta_neu': 0.21611913,
#   'roberta_pos': 0.023083465},
#  215: {'vader_neg': 0.0,
#   'vader_neu': 0.891,
#   'vader_pos': 0.109,
#   'vader_compound': 0.6476,
#   'roberta_neg': 0.0032443216,
#   'roberta_neu': 0.03989152,
#   'roberta_pos': 0.9568642},
#  216: {'vader_neg': 0.0,
#   'vader_neu': 0.798,
#   'vader_pos': 0.202,
#   'vader_compound': 0.7964,
#   'roberta_neg': 0.0017572813,
#   'roberta_neu': 0.01508038,
#   'roberta_pos': 0.9831623},
#  217: {'vader_neg': 0.078,
#   'vader_neu': 0.922,
#   'vader_pos': 0.0,
#   'vader_compound': -0.296,
#   'roberta_neg': 0.3688263,
#   'roberta_neu': 0.53968245,
#   'roberta_pos': 0.09149123},
#  218: {'vader_neg': 0.015,
#   'vader_neu': 0.884,
#   'vader_pos': 0.101,
#   'vader_compound': 0.9736,
#   'roberta_neg': 0.06660527,
#   'roberta_neu': 0.4823083,
#   'roberta_pos': 0.4510865},
#  219: {'vader_neg': 0.059,
#   'vader_neu': 0.774,
#   'vader_pos': 0.167,
#   'vader_compound': 0.9424,
#   'roberta_neg': 0.0041107573,
#   'roberta_neu': 0.039937627,
#   'roberta_pos': 0.9559516},
#  220: {'vader_neg': 0.031,
#   'vader_neu': 0.702,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9812,
#   'roberta_neg': 0.0050863214,
#   'roberta_neu': 0.03378195,
#   'roberta_pos': 0.96113175},
#  221: {'vader_neg': 0.027,
#   'vader_neu': 0.909,
#   'vader_pos': 0.064,
#   'vader_compound': 0.25,
#   'roberta_neg': 0.07303102,
#   'roberta_neu': 0.41860473,
#   'roberta_pos': 0.5083642},
#  222: {'vader_neg': 0.068,
#   'vader_neu': 0.666,
#   'vader_pos': 0.266,
#   'vader_compound': 0.9883,
#   'roberta_neg': 0.0041134357,
#   'roberta_neu': 0.0632059,
#   'roberta_pos': 0.93268067},
#  223: {'vader_neg': 0.0,
#   'vader_neu': 0.779,
#   'vader_pos': 0.221,
#   'vader_compound': 0.9623,
#   'roberta_neg': 0.0014788272,
#   'roberta_neu': 0.011571924,
#   'roberta_pos': 0.98694927},
#  224: {'vader_neg': 0.0,
#   'vader_neu': 0.607,
#   'vader_pos': 0.393,
#   'vader_compound': 0.923,
#   'roberta_neg': 0.0012665293,
#   'roberta_neu': 0.006620147,
#   'roberta_pos': 0.99211335},
#  225: {'vader_neg': 0.152,
#   'vader_neu': 0.739,
#   'vader_pos': 0.109,
#   'vader_compound': -0.25,
#   'roberta_neg': 0.9003762,
#   'roberta_neu': 0.09091951,
#   'roberta_pos': 0.00870432},
#  226: {'vader_neg': 0.064,
#   'vader_neu': 0.794,
#   'vader_pos': 0.141,
#   'vader_compound': 0.7951,
#   'roberta_neg': 0.057143483,
#   'roberta_neu': 0.15867656,
#   'roberta_pos': 0.7841799},
#  227: {'vader_neg': 0.139,
#   'vader_neu': 0.754,
#   'vader_pos': 0.108,
#   'vader_compound': -0.3774,
#   'roberta_neg': 0.010173984,
#   'roberta_neu': 0.071050294,
#   'roberta_pos': 0.91877574},
#  228: {'vader_neg': 0.106,
#   'vader_neu': 0.718,
#   'vader_pos': 0.176,
#   'vader_compound': 0.5475,
#   'roberta_neg': 0.003924316,
#   'roberta_neu': 0.06404408,
#   'roberta_pos': 0.93203163},
#  229: {'vader_neg': 0.0,
#   'vader_neu': 0.837,
#   'vader_pos': 0.163,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.3876691,
#   'roberta_neu': 0.49949262,
#   'roberta_pos': 0.11283832},
#  230: {'vader_neg': 0.025,
#   'vader_neu': 0.854,
#   'vader_pos': 0.121,
#   'vader_compound': 0.6478,
#   'roberta_neg': 0.867932,
#   'roberta_neu': 0.11575111,
#   'roberta_pos': 0.016316896},
#  231: {'vader_neg': 0.03,
#   'vader_neu': 0.726,
#   'vader_pos': 0.244,
#   'vader_compound': 0.9281,
#   'roberta_neg': 0.0012672328,
#   'roberta_neu': 0.015074653,
#   'roberta_pos': 0.98365813},
#  232: {'vader_neg': 0.0,
#   'vader_neu': 0.904,
#   'vader_pos': 0.096,
#   'vader_compound': 0.8144,
#   'roberta_neg': 0.0010959031,
#   'roberta_neu': 0.032064784,
#   'roberta_pos': 0.9668393},
#  233: {'vader_neg': 0.0,
#   'vader_neu': 0.807,
#   'vader_pos': 0.193,
#   'vader_compound': 0.8126,
#   'roberta_neg': 0.002680353,
#   'roberta_neu': 0.018354537,
#   'roberta_pos': 0.9789651},
#  234: {'vader_neg': 0.103,
#   'vader_neu': 0.729,
#   'vader_pos': 0.169,
#   'vader_compound': 0.2481,
#   'roberta_neg': 0.9334733,
#   'roberta_neu': 0.059465103,
#   'roberta_pos': 0.0070616375},
#  235: {'vader_neg': 0.0,
#   'vader_neu': 0.805,
#   'vader_pos': 0.195,
#   'vader_compound': 0.8655,
#   'roberta_neg': 0.0013840125,
#   'roberta_neu': 0.008378321,
#   'roberta_pos': 0.99023765},
#  236: {'vader_neg': 0.11,
#   'vader_neu': 0.792,
#   'vader_pos': 0.098,
#   'vader_compound': -0.4786,
#   'roberta_neg': 0.87115085,
#   'roberta_neu': 0.108774215,
#   'roberta_pos': 0.020074865},
#  237: {'vader_neg': 0.041,
#   'vader_neu': 0.793,
#   'vader_pos': 0.166,
#   'vader_compound': 0.9387,
#   'roberta_neg': 0.0022035139,
#   'roberta_neu': 0.016126273,
#   'roberta_pos': 0.98167026},
#  238: {'vader_neg': 0.029,
#   'vader_neu': 0.798,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9936,
#   'roberta_neg': 0.1414477,
#   'roberta_neu': 0.3613946,
#   'roberta_pos': 0.49715772},
#  239: {'vader_neg': 0.064,
#   'vader_neu': 0.7,
#   'vader_pos': 0.236,
#   'vader_compound': 0.9677,
#   'roberta_neg': 0.002238804,
#   'roberta_neu': 0.010961043,
#   'roberta_pos': 0.9868002},
#  240: {'vader_neg': 0.0,
#   'vader_neu': 0.72,
#   'vader_pos': 0.28,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.005628184,
#   'roberta_neu': 0.05601586,
#   'roberta_pos': 0.938356},
#  241: {'vader_neg': 0.066,
#   'vader_neu': 0.71,
#   'vader_pos': 0.223,
#   'vader_compound': 0.9553,
#   'roberta_neg': 0.015070685,
#   'roberta_neu': 0.06331338,
#   'roberta_pos': 0.9216159},
#  242: {'vader_neg': 0.0,
#   'vader_neu': 0.765,
#   'vader_pos': 0.235,
#   'vader_compound': 0.807,
#   'roberta_neg': 0.0037303367,
#   'roberta_neu': 0.025477458,
#   'roberta_pos': 0.97079223},
#  243: {'vader_neg': 0.0,
#   'vader_neu': 0.76,
#   'vader_pos': 0.24,
#   'vader_compound': 0.9344,
#   'roberta_neg': 0.00093678397,
#   'roberta_neu': 0.013776065,
#   'roberta_pos': 0.9852872},
#  244: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.2017189,
#   'roberta_neu': 0.6541579,
#   'roberta_pos': 0.14412318},
#  245: {'vader_neg': 0.081,
#   'vader_neu': 0.63,
#   'vader_pos': 0.289,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.001320415,
#   'roberta_neu': 0.02792961,
#   'roberta_pos': 0.97075},
#  246: {'vader_neg': 0.072,
#   'vader_neu': 0.825,
#   'vader_pos': 0.103,
#   'vader_compound': 0.682,
#   'roberta_neg': 0.6343514,
#   'roberta_neu': 0.29252616,
#   'roberta_pos': 0.07312241},
#  247: {'vader_neg': 0.075,
#   'vader_neu': 0.633,
#   'vader_pos': 0.292,
#   'vader_compound': 0.9757,
#   'roberta_neg': 0.0090145655,
#   'roberta_neu': 0.020562595,
#   'roberta_pos': 0.97042286},
#  248: {'vader_neg': 0.0,
#   'vader_neu': 0.869,
#   'vader_pos': 0.131,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.0049928473,
#   'roberta_neu': 0.06529995,
#   'roberta_pos': 0.9297072},
#  249: {'vader_neg': 0.0,
#   'vader_neu': 0.602,
#   'vader_pos': 0.398,
#   'vader_compound': 0.9351,
#   'roberta_neg': 0.0044303993,
#   'roberta_neu': 0.04089041,
#   'roberta_pos': 0.95467925},
#  250: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.7184,
#   'roberta_neg': 0.03698035,
#   'roberta_neu': 0.5882381,
#   'roberta_pos': 0.3747815},
#  251: {'vader_neg': 0.047,
#   'vader_neu': 0.781,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9476,
#   'roberta_neg': 0.001810416,
#   'roberta_neu': 0.012259944,
#   'roberta_pos': 0.98592967},
#  252: {'vader_neg': 0.076,
#   'vader_neu': 0.924,
#   'vader_pos': 0.0,
#   'vader_compound': -0.4823,
#   'roberta_neg': 0.19499929,
#   'roberta_neu': 0.41602737,
#   'roberta_pos': 0.38897339},
#  253: {'vader_neg': 0.107,
#   'vader_neu': 0.893,
#   'vader_pos': 0.0,
#   'vader_compound': -0.4767,
#   'roberta_neg': 0.96883047,
#   'roberta_neu': 0.028154418,
#   'roberta_pos': 0.003015119},
#  254: {'vader_neg': 0.0,
#   'vader_neu': 0.801,
#   'vader_pos': 0.199,
#   'vader_compound': 0.9698,
#   'roberta_neg': 0.022160647,
#   'roberta_neu': 0.2271491,
#   'roberta_pos': 0.7506903},
#  255: {'vader_neg': 0.091,
#   'vader_neu': 0.736,
#   'vader_pos': 0.172,
#   'vader_compound': 0.4118,
#   'roberta_neg': 0.059614304,
#   'roberta_neu': 0.31474924,
#   'roberta_pos': 0.6256365},
#  256: {'vader_neg': 0.103,
#   'vader_neu': 0.699,
#   'vader_pos': 0.198,
#   'vader_compound': 0.9805,
#   'roberta_neg': 0.3986025,
#   'roberta_neu': 0.4250449,
#   'roberta_pos': 0.17635253},
#  257: {'vader_neg': 0.034,
#   'vader_neu': 0.664,
#   'vader_pos': 0.302,
#   'vader_compound': 0.9463,
#   'roberta_neg': 0.0016951432,
#   'roberta_neu': 0.008922462,
#   'roberta_pos': 0.9893824},
#  258: {'vader_neg': 0.105,
#   'vader_neu': 0.816,
#   'vader_pos': 0.079,
#   'vader_compound': -0.3489,
#   'roberta_neg': 0.97898465,
#   'roberta_neu': 0.01878031,
#   'roberta_pos': 0.0022350603},
#  259: {'vader_neg': 0.04,
#   'vader_neu': 0.841,
#   'vader_pos': 0.119,
#   'vader_compound': 0.8883,
#   'roberta_neg': 0.102892905,
#   'roberta_neu': 0.28166282,
#   'roberta_pos': 0.6154443},
#  260: {'vader_neg': 0.0,
#   'vader_neu': 0.833,
#   'vader_pos': 0.167,
#   'vader_compound': 0.8824,
#   'roberta_neg': 0.0016668838,
#   'roberta_neu': 0.05221989,
# ...
#   'vader_compound': 0.8902,
#   'roberta_neg': 0.0036943192,
#   'roberta_neu': 0.020468503,
#   'roberta_pos': 0.97583723},
#  416: {'vader_neg': 0.0,
#   'vader_neu': 0.594,
#   'vader_pos': 0.406,
#   'vader_compound': 0.9612,
#   'roberta_neg': 0.0014899257,
#   'roberta_neu': 0.011894793,
#   'roberta_pos': 0.9866153},
#  417: {'vader_neg': 0.07,
#   'vader_neu': 0.799,
#   'vader_pos': 0.131,
#   'vader_compound': 0.9222,
#   'roberta_neg': 0.03650226,
#   'roberta_neu': 0.105736636,
#   'roberta_pos': 0.85776114},
#  418: {'vader_neg': 0.166,
#   'vader_neu': 0.809,
#   'vader_pos': 0.025,
#   'vader_compound': -0.8957,
#   'roberta_neg': 0.96256703,
#   'roberta_neu': 0.033042915,
#   'roberta_pos': 0.004390155},
#  419: {'vader_neg': 0.0,
#   'vader_neu': 0.784,
#   'vader_pos': 0.216,
#   'vader_compound': 0.8876,
#   'roberta_neg': 0.087119244,
#   'roberta_neu': 0.29397804,
#   'roberta_pos': 0.6189027},
#  420: {'vader_neg': 0.148,
#   'vader_neu': 0.815,
#   'vader_pos': 0.037,
#   'vader_compound': -0.5983,
#   'roberta_neg': 0.014699108,
#   'roberta_neu': 0.10605642,
#   'roberta_pos': 0.8792445},
#  421: {'vader_neg': 0.035,
#   'vader_neu': 0.754,
#   'vader_pos': 0.211,
#   'vader_compound': 0.9561,
#   'roberta_neg': 0.004601228,
#   'roberta_neu': 0.025528016,
#   'roberta_pos': 0.96987075},
#  422: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.2542202,
#   'roberta_neu': 0.5514286,
#   'roberta_pos': 0.19435123},
#  423: {'vader_neg': 0.223,
#   'vader_neu': 0.68,
#   'vader_pos': 0.096,
#   'vader_compound': -0.3314,
#   'roberta_neg': 0.61268765,
#   'roberta_neu': 0.31332755,
#   'roberta_pos': 0.07398477},
#  424: {'vader_neg': 0.055,
#   'vader_neu': 0.687,
#   'vader_pos': 0.258,
#   'vader_compound': 0.9106,
#   'roberta_neg': 0.004854866,
#   'roberta_neu': 0.03652874,
#   'roberta_pos': 0.95861644},
#  425: {'vader_neg': 0.017,
#   'vader_neu': 0.821,
#   'vader_pos': 0.161,
#   'vader_compound': 0.9576,
#   'roberta_neg': 0.0062578716,
#   'roberta_neu': 0.034265812,
#   'roberta_pos': 0.9594763},
#  426: {'vader_neg': 0.0,
#   'vader_neu': 0.806,
#   'vader_pos': 0.194,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.012697501,
#   'roberta_neu': 0.13296148,
#   'roberta_pos': 0.85434103},
#  427: {'vader_neg': 0.029,
#   'vader_neu': 0.817,
#   'vader_pos': 0.154,
#   'vader_compound': 0.7845,
#   'roberta_neg': 0.012627824,
#   'roberta_neu': 0.07625698,
#   'roberta_pos': 0.91111517},
#  428: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9337,
#   'roberta_neg': 0.0018590484,
#   'roberta_neu': 0.012468759,
#   'roberta_pos': 0.98567224},
#  429: {'vader_neg': 0.0,
#   'vader_neu': 0.739,
#   'vader_pos': 0.261,
#   'vader_compound': 0.9741,
#   'roberta_neg': 0.008164933,
#   'roberta_neu': 0.051790662,
#   'roberta_pos': 0.94004434},
#  430: {'vader_neg': 0.0,
#   'vader_neu': 0.617,
#   'vader_pos': 0.383,
#   'vader_compound': 0.9876,
#   'roberta_neg': 0.0016139904,
#   'roberta_neu': 0.0074673127,
#   'roberta_pos': 0.99091864},
#  431: {'vader_neg': 0.04,
#   'vader_neu': 0.786,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9847,
#   'roberta_neg': 0.006102617,
#   'roberta_neu': 0.026842162,
#   'roberta_pos': 0.9670552},
#  432: {'vader_neg': 0.0,
#   'vader_neu': 0.73,
#   'vader_pos': 0.27,
#   'vader_compound': 0.9516,
#   'roberta_neg': 0.011265207,
#   'roberta_neu': 0.08173876,
#   'roberta_pos': 0.9069961},
#  433: {'vader_neg': 0.083,
#   'vader_neu': 0.751,
#   'vader_pos': 0.166,
#   'vader_compound': 0.8044,
#   'roberta_neg': 0.018771151,
#   'roberta_neu': 0.049867086,
#   'roberta_pos': 0.9313618},
#  434: {'vader_neg': 0.108,
#   'vader_neu': 0.593,
#   'vader_pos': 0.299,
#   'vader_compound': 0.8655,
#   'roberta_neg': 0.059044294,
#   'roberta_neu': 0.075424835,
#   'roberta_pos': 0.8655309},
#  435: {'vader_neg': 0.0,
#   'vader_neu': 0.771,
#   'vader_pos': 0.229,
#   'vader_compound': 0.9179,
#   'roberta_neg': 0.0068401825,
#   'roberta_neu': 0.053331304,
#   'roberta_pos': 0.9398286},
#  436: {'vader_neg': 0.0,
#   'vader_neu': 0.829,
#   'vader_pos': 0.171,
#   'vader_compound': 0.8519,
#   'roberta_neg': 0.0037277255,
#   'roberta_neu': 0.018019224,
#   'roberta_pos': 0.97825307},
#  437: {'vader_neg': 0.0,
#   'vader_neu': 0.926,
#   'vader_pos': 0.074,
#   'vader_compound': 0.7383,
#   'roberta_neg': 0.007436048,
#   'roberta_neu': 0.13899873,
#   'roberta_pos': 0.8535653},
#  438: {'vader_neg': 0.0,
#   'vader_neu': 0.887,
#   'vader_pos': 0.113,
#   'vader_compound': 0.6369,
#   'roberta_neg': 0.0011589358,
#   'roberta_neu': 0.012277899,
#   'roberta_pos': 0.9865631},
#  439: {'vader_neg': 0.0,
#   'vader_neu': 0.728,
#   'vader_pos': 0.272,
#   'vader_compound': 0.87,
#   'roberta_neg': 0.0018007265,
#   'roberta_neu': 0.013664512,
#   'roberta_pos': 0.98453474},
#  440: {'vader_neg': 0.072,
#   'vader_neu': 0.781,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9307,
#   'roberta_neg': 0.19511487,
#   'roberta_neu': 0.46154115,
#   'roberta_pos': 0.34334406},
#  441: {'vader_neg': 0.078,
#   'vader_neu': 0.793,
#   'vader_pos': 0.129,
#   'vader_compound': 0.5176,
#   'roberta_neg': 0.057659872,
#   'roberta_neu': 0.3548919,
#   'roberta_pos': 0.58744824},
#  442: {'vader_neg': 0.054,
#   'vader_neu': 0.69,
#   'vader_pos': 0.257,
#   'vader_compound': 0.9683,
#   'roberta_neg': 0.001898036,
#   'roberta_neu': 0.0083750235,
#   'roberta_pos': 0.98972696},
#  443: {'vader_neg': 0.0,
#   'vader_neu': 0.616,
#   'vader_pos': 0.384,
#   'vader_compound': 0.9603,
#   'roberta_neg': 0.0012334296,
#   'roberta_neu': 0.007042067,
#   'roberta_pos': 0.99172455},
#  444: {'vader_neg': 0.044,
#   'vader_neu': 0.898,
#   'vader_pos': 0.058,
#   'vader_compound': 0.1882,
#   'roberta_neg': 0.19155556,
#   'roberta_neu': 0.5143031,
#   'roberta_pos': 0.2941414},
#  445: {'vader_neg': 0.055,
#   'vader_neu': 0.873,
#   'vader_pos': 0.072,
#   'vader_compound': 0.0935,
#   'roberta_neg': 0.018945245,
#   'roberta_neu': 0.1761636,
#   'roberta_pos': 0.80489117},
#  446: {'vader_neg': 0.077,
#   'vader_neu': 0.78,
#   'vader_pos': 0.143,
#   'vader_compound': 0.3699,
#   'roberta_neg': 0.50970477,
#   'roberta_neu': 0.3124165,
#   'roberta_pos': 0.17787872},
#  447: {'vader_neg': 0.042,
#   'vader_neu': 0.763,
#   'vader_pos': 0.195,
#   'vader_compound': 0.9883,
#   'roberta_neg': 0.0135505255,
#   'roberta_neu': 0.09274991,
#   'roberta_pos': 0.8936995},
#  448: {'vader_neg': 0.0,
#   'vader_neu': 0.713,
#   'vader_pos': 0.287,
#   'vader_compound': 0.967,
#   'roberta_neg': 0.0029357441,
#   'roberta_neu': 0.011814998,
#   'roberta_pos': 0.9852492},
#  449: {'vader_neg': 0.0,
#   'vader_neu': 0.737,
#   'vader_pos': 0.263,
#   'vader_compound': 0.8531,
#   'roberta_neg': 0.0017834366,
#   'roberta_neu': 0.009716061,
#   'roberta_pos': 0.9885005},
#  450: {'vader_neg': 0.0,
#   'vader_neu': 0.845,
#   'vader_pos': 0.155,
#   'vader_compound': 0.6908,
#   'roberta_neg': 0.0036159328,
#   'roberta_neu': 0.04705379,
#   'roberta_pos': 0.9493303},
#  451: {'vader_neg': 0.034,
#   'vader_neu': 0.743,
#   'vader_pos': 0.223,
#   'vader_compound': 0.9873,
#   'roberta_neg': 0.0053236857,
#   'roberta_neu': 0.040369105,
#   'roberta_pos': 0.95430726},
#  452: {'vader_neg': 0.054,
#   'vader_neu': 0.782,
#   'vader_pos': 0.164,
#   'vader_compound': 0.9337,
#   'roberta_neg': 0.12190911,
#   'roberta_neu': 0.24003696,
#   'roberta_pos': 0.63805395},
#  453: {'vader_neg': 0.0,
#   'vader_neu': 0.5,
#   'vader_pos': 0.5,
#   'vader_compound': 0.943,
#   'roberta_neg': 0.0017866727,
#   'roberta_neu': 0.0049141822,
#   'roberta_pos': 0.9932991},
#  454: {'vader_neg': 0.0,
#   'vader_neu': 0.603,
#   'vader_pos': 0.397,
#   'vader_compound': 0.8811,
#   'roberta_neg': 0.0012915937,
#   'roberta_neu': 0.007356497,
#   'roberta_pos': 0.99135196},
#  455: {'vader_neg': 0.0,
#   'vader_neu': 0.699,
#   'vader_pos': 0.301,
#   'vader_compound': 0.9619,
#   'roberta_neg': 0.0015823946,
#   'roberta_neu': 0.014091764,
#   'roberta_pos': 0.9843258},
#  456: {'vader_neg': 0.082,
#   'vader_neu': 0.854,
#   'vader_pos': 0.064,
#   'vader_compound': -0.4854,
#   'roberta_neg': 0.12627147,
#   'roberta_neu': 0.24591643,
#   'roberta_pos': 0.6278121},
#  457: {'vader_neg': 0.0,
#   'vader_neu': 0.684,
#   'vader_pos': 0.316,
#   'vader_compound': 0.926,
#   'roberta_neg': 0.0030426593,
#   'roberta_neu': 0.030558072,
#   'roberta_pos': 0.9663993},
#  458: {'vader_neg': 0.0,
#   'vader_neu': 0.564,
#   'vader_pos': 0.436,
#   'vader_compound': 0.9642,
#   'roberta_neg': 0.0016372128,
#   'roberta_neu': 0.007896157,
#   'roberta_pos': 0.99046665},
#  459: {'vader_neg': 0.045,
#   'vader_neu': 0.717,
#   'vader_pos': 0.239,
#   'vader_compound': 0.8455,
#   'roberta_neg': 0.0027739562,
#   'roberta_neu': 0.00946765,
#   'roberta_pos': 0.98775834},
#  460: {'vader_neg': 0.066,
#   'vader_neu': 0.743,
#   'vader_pos': 0.19,
#   'vader_compound': 0.9481,
#   'roberta_neg': 0.0072298073,
#   'roberta_neu': 0.019606518,
#   'roberta_pos': 0.9731637},
#  461: {'vader_neg': 0.08,
#   'vader_neu': 0.821,
#   'vader_pos': 0.099,
#   'vader_compound': 0.4883,
#   'roberta_neg': 0.51744306,
#   'roberta_neu': 0.3589137,
#   'roberta_pos': 0.12364331},
#  462: {'vader_neg': 0.037,
#   'vader_neu': 0.87,
#   'vader_pos': 0.093,
#   'vader_compound': 0.34,
#   'roberta_neg': 0.42455137,
#   'roberta_neu': 0.4280613,
#   'roberta_pos': 0.14738731},
#  463: {'vader_neg': 0.099,
#   'vader_neu': 0.794,
#   'vader_pos': 0.108,
#   'vader_compound': 0.5983,
#   'roberta_neg': 0.14180124,
#   'roberta_neu': 0.2807591,
#   'roberta_pos': 0.57743967},
#  464: {'vader_neg': 0.019,
#   'vader_neu': 0.868,
#   'vader_pos': 0.113,
#   'vader_compound': 0.8443,
#   'roberta_neg': 0.069431156,
#   'roberta_neu': 0.30800313,
#   'roberta_pos': 0.6225657},
#  465: {'vader_neg': 0.0,
#   'vader_neu': 0.838,
#   'vader_pos': 0.162,
#   'vader_compound': 0.7823,
#   'roberta_neg': 0.0043164366,
#   'roberta_neu': 0.011908594,
#   'roberta_pos': 0.98377496},
#  466: {'vader_neg': 0.0,
#   'vader_neu': 0.772,
#   'vader_pos': 0.228,
#   'vader_compound': 0.9606,
#   'roberta_neg': 0.001601023,
#   'roberta_neu': 0.0069907475,
#   'roberta_pos': 0.99140817},
#  467: {'vader_neg': 0.009,
#   'vader_neu': 0.845,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9874,
#   'roberta_neg': 0.006954097,
#   'roberta_neu': 0.11868079,
#   'roberta_pos': 0.8743651},
#  468: {'vader_neg': 0.008,
#   'vader_neu': 0.818,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9926,
#   'roberta_neg': 0.0049444973,
#   'roberta_neu': 0.10956268,
#   'roberta_pos': 0.8854928},
#  469: {'vader_neg': 0.049,
#   'vader_neu': 0.951,
#   'vader_pos': 0.0,
#   'vader_compound': -0.3595,
#   'roberta_neg': 0.007455903,
#   'roberta_neu': 0.049894657,
#   'roberta_pos': 0.9426494},
#  470: {'vader_neg': 0.0,
#   'vader_neu': 0.957,
#   'vader_pos': 0.043,
#   'vader_compound': 0.25,
#   'roberta_neg': 0.0024990672,
#   'roberta_neu': 0.025668936,
#   'roberta_pos': 0.971832},
#  471: {'vader_neg': 0.051,
#   'vader_neu': 0.676,
#   'vader_pos': 0.273,
#   'vader_compound': 0.9749,
#   'roberta_neg': 0.034362182,
#   'roberta_neu': 0.14488828,
#   'roberta_pos': 0.8207496},
#  472: {'vader_neg': 0.0,
#   'vader_neu': 0.565,
#   'vader_pos': 0.435,
#   'vader_compound': 0.9649,
#   'roberta_neg': 0.013430158,
#   'roberta_neu': 0.109873794,
#   'roberta_pos': 0.876696},
#  473: {'vader_neg': 0.0,
#   'vader_neu': 0.686,
#   'vader_pos': 0.314,
#   'vader_compound': 0.7506,
#   'roberta_neg': 0.0033767174,
#   'roberta_neu': 0.023373839,
#   'roberta_pos': 0.97324944},
#  474: {'vader_neg': 0.013,
#   'vader_neu': 0.75,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9828,
#   'roberta_neg': 0.01760331,
#   'roberta_neu': 0.07281259,
#   'roberta_pos': 0.90958405},
#  475: {'vader_neg': 0.0,
#   'vader_neu': 0.585,
#   'vader_pos': 0.415,
#   'vader_compound': 0.9095,
#   'roberta_neg': 0.0014492898,
#   'roberta_neu': 0.0075233183,
#   'roberta_pos': 0.9910274},
#  476: {'vader_neg': 0.066,
#   'vader_neu': 0.614,
#   'vader_pos': 0.32,
#   'vader_compound': 0.9684,
#   'roberta_neg': 0.0035778931,
#   'roberta_neu': 0.011040189,
#   'roberta_pos': 0.98538184},
#  477: {'vader_neg': 0.034,
#   'vader_neu': 0.728,
#   'vader_pos': 0.238,
#   'vader_compound': 0.8555,
#   'roberta_neg': 0.0015812092,
#   'roberta_neu': 0.013900251,
#   'roberta_pos': 0.9845185},
#  478: {'vader_neg': 0.0,
#   'vader_neu': 0.823,
#   'vader_pos': 0.177,
#   'vader_compound': 0.6239,
#   'roberta_neg': 0.021452915,
#   'roberta_neu': 0.078850575,
#   'roberta_pos': 0.89969647},
#  479: {'vader_neg': 0.245,
#   'vader_neu': 0.652,
#   'vader_pos': 0.103,
#   'vader_compound': -0.3855,
#   'roberta_neg': 0.18732393,
#   'roberta_neu': 0.50657755,
#   'roberta_pos': 0.30609852},
#  480: {'vader_neg': 0.0,
#   'vader_neu': 0.435,
#   'vader_pos': 0.565,
#   'vader_compound': 0.9935,
#   'roberta_neg': 0.002328618,
#   'roberta_neu': 0.01353393,
#   'roberta_pos': 0.98413754},
#  481: {'vader_neg': 0.022,
#   'vader_neu': 0.728,
#   'vader_pos': 0.249,
#   'vader_compound': 0.9451,
#   'roberta_neg': 0.021744134,
#   'roberta_neu': 0.065837264,
#   'roberta_pos': 0.9124186},
#  482: {'vader_neg': 0.0,
#   'vader_neu': 0.605,
#   'vader_pos': 0.395,
#   'vader_compound': 0.9079,
#   'roberta_neg': 0.0013218175,
#   'roberta_neu': 0.00969551,
#   'roberta_pos': 0.9889826},
#  483: {'vader_neg': 0.0,
#   'vader_neu': 0.862,
#   'vader_pos': 0.138,
#   'vader_compound': 0.3384,
#   'roberta_neg': 0.0016637422,
#   'roberta_neu': 0.012073511,
#   'roberta_pos': 0.9862627},
#  484: {'vader_neg': 0.088,
#   'vader_neu': 0.767,
#   'vader_pos': 0.145,
#   'vader_compound': 0.4516,
#   'roberta_neg': 0.8551747,
#   'roberta_neu': 0.12534124,
#   'roberta_pos': 0.019484114},
#  485: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.8547,
#   'roberta_neg': 0.080300555,
#   'roberta_neu': 0.22237739,
#   'roberta_pos': 0.6973221},
#  486: {'vader_neg': 0.0,
#   'vader_neu': 0.818,
#   'vader_pos': 0.182,
#   'vader_compound': 0.9224,
#   'roberta_neg': 0.00965573,
#   'roberta_neu': 0.107732326,
#   'roberta_pos': 0.882612},
#  487: {'vader_neg': 0.0,
#   'vader_neu': 0.909,
#   'vader_pos': 0.091,
#   'vader_compound': 0.296,
#   'roberta_neg': 0.16178502,
#   'roberta_neu': 0.54138005,
#   'roberta_pos': 0.29683495},
#  488: {'vader_neg': 0.179,
#   'vader_neu': 0.707,
#   'vader_pos': 0.114,
#   'vader_compound': -0.3723,
#   'roberta_neg': 0.71046406,
#   'roberta_neu': 0.19951256,
#   'roberta_pos': 0.09002336},
#  489: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.9598,
#   'roberta_neg': 0.10650093,
#   'roberta_neu': 0.3259607,
#   'roberta_pos': 0.5675384},
#  490: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9788,
#   'roberta_neg': 0.0017469625,
#   'roberta_neu': 0.017913941,
#   'roberta_pos': 0.9803391},
#  491: {'vader_neg': 0.055,
#   'vader_neu': 0.704,
#   'vader_pos': 0.241,
#   'vader_compound': 0.9287,
#   'roberta_neg': 0.60727084,
#   'roberta_neu': 0.28218284,
#   'roberta_pos': 0.110546336},
#  492: {'vader_neg': 0.0,
#   'vader_neu': 0.717,
#   'vader_pos': 0.283,
#   'vader_compound': 0.9367,
#   'roberta_neg': 0.00205126,
#   'roberta_neu': 0.013804731,
#   'roberta_pos': 0.984144},
#  493: {'vader_neg': 0.056,
#   'vader_neu': 0.855,
#   'vader_pos': 0.089,
#   'vader_compound': 0.5976,
#   'roberta_neg': 0.17750019,
#   'roberta_neu': 0.3094604,
#   'roberta_pos': 0.5130394},
#  494: {'vader_neg': 0.1,
#   'vader_neu': 0.645,
#   'vader_pos': 0.254,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.29517853,
#   'roberta_neu': 0.53552115,
#   'roberta_pos': 0.16930027},
#  495: {'vader_neg': 0.0,
#   'vader_neu': 0.788,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9743,
#   'roberta_neg': 0.0044860737,
#   'roberta_neu': 0.027288666,
#   'roberta_pos': 0.9682253},
#  496: {'vader_neg': 0.0,
#   'vader_neu': 0.554,
#   'vader_pos': 0.446,
#   'vader_compound': 0.9725,
#   'roberta_neg': 0.0019062845,
#   'roberta_neu': 0.009861636,
#   'roberta_pos': 0.9882321},
#  497: {'vader_neg': 0.059,
#   'vader_neu': 0.799,
#   'vader_pos': 0.142,
#   'vader_compound': 0.7833,
#   'roberta_neg': 0.0044153826,
#   'roberta_neu': 0.034215398,
#   'roberta_pos': 0.9613692},
#  498: {'vader_neg': 0.025,
#   'vader_neu': 0.762,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9848,
#   'roberta_neg': 0.006426537,
#   'roberta_neu': 0.07453733,
#   'roberta_pos': 0.91903615},
#  499: {'vader_neg': 0.041,
#   'vader_neu': 0.904,
#   'vader_pos': 0.055,
#   'vader_compound': 0.128,
#   'roberta_neg': 0.86561406,
#   'roberta_neu': 0.119366,
#   'roberta_pos': 0.01501989},
#  500: {'vader_neg': 0.0,
#   'vader_neu': 0.678,
#   'vader_pos': 0.322,
#   'vader_compound': 0.9811,
#   'roberta_neg': 0.0024397594,
#   'roberta_neu': 0.011327237,
#   'roberta_pos': 0.986233}}

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index':'Id'})
results_df = results_df.merge(df, on='Id', how='left')

# %%
results_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098068     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Compare score between models

# %%
results_df.columns
# Out:
# Index(['Id', 'vader_neg', 'vader_neu', 'vader_pos', 'vader_compound',
#        'roberta_neg', 'roberta_neu', 'roberta_pos', 'ProductId', 'UserId',
#        'ProfileName', 'HelpfulnessNumerator', 'HelpfulnessDenominator',
#        'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
sns.pairplot(data = results_df, vars = ['vader_neg', 'vader_neu', 'vader_pos',
       'roberta_neg', 'roberta_neu', 'roberta_pos'], hue='Score', palette='tab10')
plt.show()

# %% [markdown]
#  ## Transformer Pipeline

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
sent_pipeline('I love sentiment analysis')
# Out:
# [{'label': 'POSITIVE', 'score': 0.999736487865448}]
